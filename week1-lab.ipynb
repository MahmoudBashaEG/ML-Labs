# %%
var = 20
var2 = 30
gun = "cuma"
print(var)
print(var2)
print(gun)
type(gun)
# Out:
# 20
# 30
# cuma
# str

# %%
#List

var1 = 5
var2 = 10
var3 = 20
list_int = [5,10,20]
type(list_int)
# Out:
# list

# %%
list_int[0]
# Out:
# 5

# %%
#Last element of the list
list_int[-1]
# Out:
# 20

# %%
list_int[0:3]
# Out:
# [5, 10, 20]

# %%
list_int.append(30)
print(list_int)
# Out:
# [5, 10, 20, 30]

# %%
list_int.remove(30)

# %%
print(list_int)
# Out:
# [5, 10, 20]

# %%
list_int.reverse()
print(list_int)
# Out:
# [20, 10, 5]

# %%
list_int.sort()
print(list_int)
# Out:
# [5, 10, 20]

# %%
max = 10
for each in list_int:
    if(each > max ):
        max = each
    else:
        continue
        
print(max)
# Out:
# 20

# %%
i = 0
while(i<5):
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def cember_cevre(r,pi=3.14): # Pi is a default value
    result = 2*pi*r
    return result

cember_cevre(2)
# Out:
# 12.56

# %%
def hesapla(x):
    result = x * x
    return result

sonuc = hesapla(2)
print(sonuc)

#Another way
sonuc2 = lambda x: x*x
print(sonuc2(2))
# Out:
# 4
# 4

# %%
dictionary = {"Mahmoud":24,"Ahmed":27,"Mohamed":28}
print(dictionary)
# Out:
# {'Mahmoud': 24, 'Ahmed': 27, 'Mohamed': 28}

# %%
type(dictionary)
# Out:
# dict

# %%
dictionary.keys()
# Out:
# dict_keys(['Mahmoud', 'Ahmed', 'Mohamed'])

# %%
dictionary.values()
# Out:
# dict_values([24, 27, 28])

# %%
keys = dictionary.keys()
if "Mahmoud" in keys:
    print("The name is exist!")
else:
    print("The name is not exist!")
# Out:
# The name is exist!

# %%
keys = dictionary.keys()
if "Omar" in keys:
    print("The name is exist!")
else:
    print("The name is not exist!")
# Out:
# The name is not exist!
